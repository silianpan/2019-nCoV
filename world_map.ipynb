# %% [markdown]
# # 疫情地图-全球数据

# %%
import numpy as np
import pandas as pd

# 导入matplotlib库中的额pyplot
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; warnings.filterwarnings(action='once')
# 让图表直接在Jupyter notebook中展示出来
# %matplotlib inline

# 一个cell输出多行语句
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# pyecharts
from pyecharts.charts import Bar
from pyecharts import options as opts
# 内置主题类型可查看 pyecharts.globals.ThemeType
from pyecharts.globals import ThemeType

plt.style.use('seaborn-whitegrid')
sns.set_style("white")
large = 22; med = 16; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (16, 10),
          'axes.labelsize': med,
          'axes.titlesize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large,
          # 解决负号无法正常显示的问题
          'axes.unicode_minus': False,
          # 解决中文乱码问题
          'font.sans-serif': ['SimHei']}
plt.rcParams.update(params)
# 默认设置下matplotlib做出来的图标不是很清晰，可以将图表设置成矢量格式显示
# %config InlineBackend.figure_format = 'svg'

# Version
print(mpl.__version__)  #> 3.0.0
print(sns.__version__)  #> 0.9.0
# Out:
# 3.1.1
# 0.9.0
# //anaconda3/lib/python3.7/site-packages/pyecharts/render/engine.py:2: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Iterable

# %%
# Prepare Data
df = pd.read_csv('data/csv/DXYArea.csv', encoding='utf8')
df.loc[0]
# 过滤数据
df = df[(df['province_confirmedCount'] > 1000) & (df['countryName'] == df['provinceName'])]
# 1. 分组拆分
# df = df.groupby('countryName')[['province_confirmedCount']].max()

# 2. 分组-应用-拆分
def topNotZero(df):
#     return df.sort_values(by=['updateTime', 'province_confirmedCount'], ascending=False)
    return df[(df['updateTime'] == df['updateTime'].max()) & (df['province_confirmedCount'] == df['province_confirmedCount'].max())]
df = df.groupby('countryName').apply(topNotZero)

df['colors'] = ['green' if x < 5000 else 'red' for x in df['province_confirmedCount']]
df.sort_values('province_confirmedCount', ascending=True, inplace=True)
df.drop('countryName', axis=1, inplace=True)
df.reset_index(inplace=True)
df.tail(10)

# Draw plot
plt.figure(figsize=(10,20), dpi= 80)
plt.hlines(y=df.index, xmin=0, xmax=df['province_confirmedCount'], color=df['colors'], alpha=0.4, linewidth=5)

# Decorations
# gca：当前的子图；gcf：当前图表figure
plt.gca().set(ylabel='国家', xlabel='人数')
plt.yticks(df.index, df['countryName'], fontsize=12)
plt.title('全球累计确诊人数', fontdict={'size':20})
plt.grid(linestyle='--', alpha=0.5)
for x, y in zip(df['province_confirmedCount'], df.index):
    plt.text(x+20000, y, str(x), ha='center', va='center', fontsize=10.5)
plt.show()
# Out:
# continentName                               亚洲
# continentEnglishName                      Asia
# countryName                                 印度
# countryEnglishName                       India
# provinceName                                印度
# provinceEnglishName                      India
# province_zipCode                        953003
# province_confirmedCount                  15712
# province_suspectedCount                      0
# province_curedCount                       2231
# province_deadCount                         507
# updateTime                 2020-04-19 13:51:59
# cityName                                   NaN
# cityEnglishName                            NaN
# city_zipCode                               NaN
# city_confirmedCount                        NaN
# city_suspectedCount                        NaN
# city_curedCount                            NaN
# city_deadCount                             NaN
# Name: 0, dtype: object
#    countryName  level_1 continentName continentEnglishName  \
# 68         比利时      145            欧洲               Europe
# 69          伊朗      148            亚洲                 Asia
# 70         土耳其       13            亚洲                 Asia
# 71          中国      295            亚洲                 Asia
# 72          法国      141            欧洲               Europe
# 73          英国      138            欧洲               Europe
# 74          德国       11            欧洲               Europe
# 75         意大利      137            欧洲               Europe
# 76         西班牙      139            欧洲               Europe
# 77          美国       10           北美洲        North America
#
#           countryEnglishName provinceName       provinceEnglishName  \
# 68                   Belgium          比利时                   Belgium
# 69                      Iran           伊朗                      Iran
# 70                    Turkey          土耳其                    Turkey
# 71                     China           中国                     China
# 72                    France           法国                    France
# 73            United Kingdom           英国            United Kingdom
# 74                   Germany           德国                   Germany
# 75                     Italy          意大利                     Italy
# 76                     Spain          西班牙                     Spain
# 77  United States of America           美国  United States of America
#
#     province_zipCode  province_confirmedCount  province_suspectedCount  ...  \
# 68            961001                    37183                      0.0  ...
# 69            955007                    80868                      0.0  ...
# 70            955018                    82329                      0.0  ...
# 71            951001                    84201                      0.0  ...
# 72            961002                   111821                      0.0  ...
# 73            961007                   114217                      0.0  ...
# 74            963003                   139897                      0.0  ...
# 75            965008                   175925                      0.0  ...
# 76            965015                   191726                      0.0  ...
# 77            971002                   734969                      0.0  ...
#
#     province_deadCount           updateTime cityName cityEnglishName  \
# 68                5453  2020-04-19 10:01:23      NaN             NaN
# 69                5031  2020-04-19 10:01:23      NaN             NaN
# 70                1890  2020-04-19 11:20:41      NaN             NaN
# 71                4642  2020-04-19 09:36:50      NaN             NaN
# 72               19323  2020-04-19 10:01:23      NaN             NaN
# 73               15464  2020-04-19 10:01:23      NaN             NaN
# 74                4294  2020-04-19 11:22:43      NaN             NaN
# 75               23227  2020-04-19 10:01:23      NaN             NaN
# 76               20043  2020-04-19 10:01:23      NaN             NaN
# 77               38903  2020-04-19 11:23:43      NaN             NaN
#
#    city_zipCode  city_confirmedCount  city_suspectedCount  city_curedCount  \
# 68          NaN                  NaN                  NaN              NaN
# 69          NaN                  NaN                  NaN              NaN
# 70          NaN                  NaN                  NaN              NaN
# 71          NaN                  NaN                  NaN              NaN
# 72          NaN                  NaN                  NaN              NaN
# 73          NaN                  NaN                  NaN              NaN
# 74          NaN                  NaN                  NaN              NaN
# 75          NaN                  NaN                  NaN              NaN
# 76          NaN                  NaN                  NaN              NaN
# 77          NaN                  NaN                  NaN              NaN
#
#     city_deadCount  colors
# 68             NaN     red
# 69             NaN     red
# 70             NaN     red
# 71             NaN     red
# 72             NaN     red
# 73             NaN     red
# 74             NaN     red
# 75             NaN     red
# 76             NaN     red
# 77             NaN     red
#
# [10 rows x 21 columns]
# [Text(0, 0.5, '国家'), Text(0.5, 0, '人数')]
# ([<matplotlib.axis.YTick at 0x1a24163ed0>,
#   <matplotlib.axis.YTick at 0x11cf10b90>,
#   <matplotlib.axis.YTick at 0x1a24162750>,
#   <matplotlib.axis.YTick at 0x10be1e8d0>,
#   <matplotlib.axis.YTick at 0x10be1e650>,
#   <matplotlib.axis.YTick at 0x10be1e490>,
#   <matplotlib.axis.YTick at 0x10be27610>,
#   <matplotlib.axis.YTick at 0x10be27c50>,
#   <matplotlib.axis.YTick at 0x10be25310>,
#   <matplotlib.axis.YTick at 0x10be25850>,
#   <matplotlib.axis.YTick at 0x10be25d90>,
#   <matplotlib.axis.YTick at 0x10be25490>,
#   <matplotlib.axis.YTick at 0x10be27bd0>,
#   <matplotlib.axis.YTick at 0x10be2e290>,
#   <matplotlib.axis.YTick at 0x10be2ea90>,
#   <matplotlib.axis.YTick at 0x10be34050>,
#   <matplotlib.axis.YTick at 0x10be34750>,
#   <matplotlib.axis.YTick at 0x10be34d90>,
#   <matplotlib.axis.YTick at 0x10be37410>,
#   <matplotlib.axis.YTick at 0x10be37a50>,
#   <matplotlib.axis.YTick at 0x10be37d90>,
#   <matplotlib.axis.YTick at 0x10be37bd0>,
#   <matplotlib.axis.YTick at 0x10be2e590>,
#   <matplotlib.axis.YTick at 0x10be3b6d0>,
#   <matplotlib.axis.YTick at 0x10be3bc50>,
#   <matplotlib.axis.YTick at 0x10be3e2d0>,
#   <matplotlib.axis.YTick at 0x10be3e910>,
#   <matplotlib.axis.YTick at 0x10be3e7d0>,
#   <matplotlib.axis.YTick at 0x10be405d0>,
#   <matplotlib.axis.YTick at 0x10be40c10>,
#   <matplotlib.axis.YTick at 0x10be43290>,
#   <matplotlib.axis.YTick at 0x10be404d0>,
#   <matplotlib.axis.YTick at 0x10be3b410>,
#   <matplotlib.axis.YTick at 0x10be43750>,
#   <matplotlib.axis.YTick at 0x10be43d90>,
#   <matplotlib.axis.YTick at 0x10be46410>,
#   <matplotlib.axis.YTick at 0x10be46a50>,
#   <matplotlib.axis.YTick at 0x10be46d90>,
#   <matplotlib.axis.YTick at 0x10be4a710>,
#   <matplotlib.axis.YTick at 0x10be4ad50>,
#   <matplotlib.axis.YTick at 0x10be4a250>,
#   <matplotlib.axis.YTick at 0x10be46290>,
#   <matplotlib.axis.YTick at 0x10be3bb50>,
#   <matplotlib.axis.YTick at 0x1a1f954990>,
#   <matplotlib.axis.YTick at 0x1a1f954a90>,
#   <matplotlib.axis.YTick at 0x1a1f957650>,
#   <matplotlib.axis.YTick at 0x1a1f957c90>,
#   <matplotlib.axis.YTick at 0x1a1f95b310>,
#   <matplotlib.axis.YTick at 0x1a1f95b950>,
#   <matplotlib.axis.YTick at 0x1a1f95b810>,
#   <matplotlib.axis.YTick at 0x1a1f95bf10>,
#   <matplotlib.axis.YTick at 0x1a1f954890>,
#   <matplotlib.axis.YTick at 0x1a1f95d290>,
#   <matplotlib.axis.YTick at 0x1a1f95db50>,
#   <matplotlib.axis.YTick at 0x1a1f960250>,
#   <matplotlib.axis.YTick at 0x1a1f960810>,
#   <matplotlib.axis.YTick at 0x1a1f960e50>,
#   <matplotlib.axis.YTick at 0x1a1f9634d0>,
#   <matplotlib.axis.YTick at 0x1a1f963b10>,
#   <matplotlib.axis.YTick at 0x1a1f9661d0>,
#   <matplotlib.axis.YTick at 0x1a1f963590>,
#   <matplotlib.axis.YTick at 0x1a1f95d690>,
#   <matplotlib.axis.YTick at 0x1a1f966650>,
#   <matplotlib.axis.YTick at 0x1a1f966c90>,
#   <matplotlib.axis.YTick at 0x1a1f968310>,
#   <matplotlib.axis.YTick at 0x1a1f968950>,
#   <matplotlib.axis.YTick at 0x1a1f968810>,
#   <matplotlib.axis.YTick at 0x1a1f96b610>,
#   <matplotlib.axis.YTick at 0x1a1f96bc50>,
#   <matplotlib.axis.YTick at 0x1a1f96b150>,
#   <matplotlib.axis.YTick at 0x1a1f968190>,
#   <matplotlib.axis.YTick at 0x1a1f95d250>,
#   <matplotlib.axis.YTick at 0x1a1f96e890>,
#   <matplotlib.axis.YTick at 0x1a1f96eed0>,
#   <matplotlib.axis.YTick at 0x1a1f973550>,
#   <matplotlib.axis.YTick at 0x1a1f973b90>,
#   <matplotlib.axis.YTick at 0x1a1f97b290>,
#   <matplotlib.axis.YTick at 0x1a1f97b850>],
#  <a list of 78 Text yticklabel objects>)
# Text(0.5, 1.0, '全球累计确诊人数')
# Text(21016, 0, '1016')
# Text(21068, 1, '1068')
# Text(21089, 2, '1089')
# Text(21098, 3, '1098')
# Text(21170, 4, '1170')
# Text(21180, 5, '1180')
# Text(21239, 6, '1239')
# Text(21245, 7, '1245')
# Text(21248, 8, '1248')
# Text(21317, 9, '1317')
# Text(21373, 10, '1373')
# Text(21450, 11, '1450')
# Text(21512, 12, '1512')
# Text(21513, 13, '1513')
# Text(21654, 14, '1654')
# Text(21751, 15, '1751')
# Text(21760, 16, '1760')
# Text(21767, 17, '1767')
# Text(21832, 18, '1832')
# Text(21834, 19, '1834')
# Text(22144, 20, '2144')
# Text(22235, 21, '2235')
# Text(22351, 22, '2351')
# Text(22534, 23, '2534')
# Text(22685, 24, '2685')
# Text(22694, 25, '2694')
# Text(22765, 26, '2765')
# Text(23032, 27, '3032')
# Text(23034, 28, '3034')
# Text(23537, 29, '3537')
# Text(23621, 30, '3621')
# Text(23681, 31, '3681')
# Text(24016, 32, '4016')
# Text(24126, 33, '4126')
# Text(24779, 34, '4779')
# Text(25008, 35, '5008')
# Text(25106, 36, '5106')
# Text(25305, 37, '5305')
# Text(25992, 38, '5992')
# Text(26087, 39, '6087')
# Text(26170, 40, '6170')
# Text(26248, 41, '6248')
# Text(26302, 42, '6302')
# Text(26586, 43, '6586')
# Text(26606, 44, '6606')
# Text(27036, 45, '7036')
# Text(27242, 46, '7242')
# Text(27497, 47, '7497')
# Text(27773, 48, '7773')
# Text(28274, 49, '8274')
# Text(28418, 50, '8418')
# Text(28742, 51, '8742')
# Text(29022, 52, '9022')
# Text(29730, 53, '9730')
# Text(30437, 54, '10437')
# Text(30661, 55, '10661')
# Text(33265, 56, '13265')
# Text(33967, 57, '13967')
# Text(34420, 58, '14420')
# Text(34662, 59, '14662')
# Text(34758, 60, '14758')
# Text(35712, 61, '15712')
# Text(39685, 62, '19685')
# Text(47201, 63, '27201')
# Text(51589, 64, '31589')
# Text(53383, 65, '33383')
# Text(56599, 66, '36599')
# Text(56793, 67, '36793')
# Text(57183, 68, '37183')
# Text(100868, 69, '80868')
# Text(102329, 70, '82329')
# Text(104201, 71, '84201')
# Text(131821, 72, '111821')
# Text(134217, 73, '114217')
# Text(159897, 74, '139897')
# Text(195925, 75, '175925')
# Text(211726, 76, '191726')
# Text(754969, 77, '734969')

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar

b = Bar(dict(height="900px"))
b.add_xaxis(list(df['countryName']))
b.add_yaxis("现存确诊人数", list(df['province_confirmedCount']))
b.reversal_axis()
b.set_series_opts(label_opts=opts.LabelOpts(position="right"))
b.set_global_opts(title_opts=opts.TitleOpts(title="全球累计确诊人数", pos_top="top"),
                  legend_opts=opts.LegendOpts(is_show=False))
b.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="58ac5e849e114dfd8dd01367d6643e23" style="width:900px; height:900px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_58ac5e849e114dfd8dd01367d6643e23 = echarts.init(
#                     document.getElementById('58ac5e849e114dfd8dd01367d6643e23'), 'white', {renderer: 'canvas'});
#                 var option_58ac5e849e114dfd8dd01367d6643e23 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u73b0\u5b58\u786e\u8bca\u4eba\u6570",
#             "data": [
#                 1016,
#                 1068,
#                 1089,
#                 1098,
#                 1170,
#                 1180,
#                 1239,
#                 1245,
#                 1248,
#                 1317,
#                 1373,
#                 1450,
#                 1512,
#                 1513,
#                 1654,
#                 1751,
#                 1760,
#                 1767,
#                 1832,
#                 1834,
#                 2144,
#                 2235,
#                 2351,
#                 2534,
#                 2685,
#                 2694,
#                 2765,
#                 3032,
#                 3034,
#                 3537,
#                 3621,
#                 3681,
#                 4016,
#                 4126,
#                 4779,
#                 5008,
#                 5106,
#                 5305,
#                 5992,
#                 6087,
#                 6170,
#                 6248,
#                 6302,
#                 6586,
#                 6606,
#                 7036,
#                 7242,
#                 7497,
#                 7773,
#                 8274,
#                 8418,
#                 8742,
#                 9022,
#                 9730,
#                 10437,
#                 10661,
#                 13265,
#                 13967,
#                 14420,
#                 14662,
#                 14758,
#                 15712,
#                 19685,
#                 27201,
#                 31589,
#                 33383,
#                 36599,
#                 36793,
#                 37183,
#                 80868,
#                 82329,
#                 84201,
#                 111821,
#                 114217,
#                 139897,
#                 175925,
#                 191726,
#                 734969
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u73b0\u5b58\u786e\u8bca\u4eba\u6570"
#             ],
#             "selected": {
#                 "\u73b0\u5b58\u786e\u8bca\u4eba\u6570": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5580\u9ea6\u9686",
#                 "\u6ce2\u591a\u9ece\u5404",
#                 "\u65af\u6d1b\u4f10\u514b",
#                 "\u65b0\u897f\u5170",
#                 "\u5317\u9a6c\u5176\u987f",
#                 "\u963f\u66fc",
#                 "\u7acb\u9676\u5b9b",
#                 "\u6ce2\u9ed1",
#                 "\u4e9a\u7f8e\u5c3c\u4e9a",
#                 "\u65af\u6d1b\u6587\u5c3c\u4e9a",
#                 "\u963f\u585e\u62dc\u7586",
#                 "\u4e4c\u5179\u522b\u514b\u65af\u5766",
#                 "\u7231\u6c99\u5c3c\u4e9a",
#                 "\u4f0a\u62c9\u514b",
#                 "\u54c8\u8428\u514b\u65af\u5766",
#                 "\u79d1\u5a01\u7279",
#                 "\u51b0\u5c9b",
#                 "\u5df4\u6797",
#                 "\u514b\u7f57\u5730\u4e9a",
#                 "\u5308\u7259\u5229",
#                 "\u5b5f\u52a0\u62c9\u56fd",
#                 "\u5e0c\u814a",
#                 "\u6469\u5c14\u591a\u74e6",
#                 "\u963f\u5c14\u53ca\u5229\u4e9a",
#                 "\u6469\u6d1b\u54e5",
#                 "\u963f\u6839\u5ef7",
#                 "\u6cf0\u56fd",
#                 "\u57c3\u53ca",
#                 "\u5357\u975e",
#                 "\u5362\u68ee\u5821",
#                 "\u54e5\u4f26\u6bd4\u4e9a",
#                 "\u82ac\u5170",
#                 "\u5df4\u62ff\u9a6c",
#                 "\u591a\u7c73\u5c3c\u52a0",
#                 "\u767d\u4fc4\u7f57\u65af",
#                 "\u5361\u5854\u5c14",
#                 "\u4e4c\u514b\u5170",
#                 "\u9a6c\u6765\u897f\u4e9a",
#                 "\u65b0\u52a0\u5761",
#                 "\u83f2\u5f8b\u5bbe",
#                 "\u585e\u5c14\u7ef4\u4e9a",
#                 "\u5370\u5ea6\u5c3c\u897f\u4e9a",
#                 "\u963f\u8054\u914b",
#                 "\u6fb3\u5927\u5229\u4e9a",
#                 "\u6377\u514b",
#                 "\u632a\u5a01",
#                 "\u4e39\u9ea6",
#                 "\u58a8\u897f\u54e5",
#                 "\u5df4\u57fa\u65af\u5766",
#                 "\u6c99\u7279\u963f\u62c9\u4f2f",
#                 "\u7f57\u9a6c\u5c3c\u4e9a",
#                 "\u6ce2\u5170",
#                 "\u5384\u74dc\u591a\u5c14",
#                 "\u667a\u5229",
#                 "\u65e5\u672c",
#                 "\u97e9\u56fd",
#                 "\u4ee5\u8272\u5217",
#                 "\u745e\u5178",
#                 "\u79d8\u9c81",
#                 "\u5965\u5730\u5229",
#                 "\u7231\u5c14\u5170",
#                 "\u5370\u5ea6",
#                 "\u8461\u8404\u7259",
#                 "\u745e\u58eb",
#                 "\u8377\u5170",
#                 "\u52a0\u62ff\u5927",
#                 "\u5df4\u897f",
#                 "\u4fc4\u7f57\u6

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from utils.country_name_map import name_map

# Prepare Data
df = pd.read_csv('data/csv/DXYArea.csv', encoding='utf8')
# 过滤数据
df = df[df['countryName'] == df['provinceName']]
# 分组-应用-拆分
def topNotZero(df):
    return df[(df['updateTime'] == df['updateTime'].max()) & (df['province_confirmedCount'] == df['province_confirmedCount'].max())]
df = df.groupby('countryName').apply(topNotZero)

df.sort_values('province_confirmedCount', ascending=True, inplace=True)
df.drop('countryName', axis=1, inplace=True)
df.reset_index(inplace=True)

# 绘图
m = Map()
m.add("现存确诊人数", [list(z) for z in zip(list(df['countryName']), list(df['province_confirmedCount']))],
      "world", name_map=name_map,
     is_map_symbol_show=False)
m.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m.set_global_opts(
    title_opts=opts.TitleOpts(title="全球疫情地图"),
    visualmap_opts=opts.VisualMapOpts(max_=800000,
                                      is_piecewise=True,
#                                       range_size=[100, 1000, 5000, 10000, 50000],
                                      range_color=['#fcefda', '#f8d3a6', '#ef8c6c', '#d5564e', '#b92b23', '#8f1f19'],
#                                       range_text=['1-99人', '100-999人', '1000-4999人', '5000-9999人', '10000-49999人', '50000人及以上'],
                                      pieces=[
                                          {'max': 100},
                                          {'max': 1000},
                                          {'max': 5000},
                                          {'max': 10000},
                                          {'max': 50000},
                                          {'min': 50000}
                                      ]),
    legend_opts=opts.LegendOpts(is_show=False)
)
m.render('COVID-19-world.html')
m.render_notebook()
# Out:
# '/Users/panliu/personal/COVID-19-Analysis/COVID-19-world.html'
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="93fe84ebf7cd4acba7fef8fc74a9a5f2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_93fe84ebf7cd4acba7fef8fc74a9a5f2 = echarts.init(
#                     document.getElementById('93fe84ebf7cd4acba7fef8fc74a9a5f2'), 'white', {renderer: 'canvas'});
#                 var option_93fe84ebf7cd4acba7fef8fc74a9a5f2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u73b0\u5b58\u786e\u8bca\u4eba\u6570",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "\u4e5f\u95e8\u5171\u548c\u56fd",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5317\u7231\u5c14\u5170",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5723\u76ae\u57c3\u5c14\u548c\u5bc6\u514b\u9686\u7fa4\u5c9b",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u82f1\u5c5e\u7ef4\u5c14\u4eac\u7fa4\u5c9b",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5723\u5df4\u6cf0\u52d2\u7c73",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5b89\u572d\u62c9",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5357\u82cf\u4e39",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5723\u591a\u7f8e\u548c\u666e\u6797\u897f\u6bd4",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u8377\u5170\u52a0\u52d2\u6bd4\u5730\u533a",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u4e0d\u4e39",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u7559\u5c3c\u6c6a",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5723\u5df4\u6cf0\u52d2\u7c73\u5c9b",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5e03\u9686\u8fea\u5171\u548c\u56fd",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u6bdb\u91cc\u5854\u5c3c\u4e9a",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u5df4\u5e03\u4e9a\u65b0\u51e0\u5185\u4e9a",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u68b5\u8482\u5188",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u5c3c\u52a0\u62c9\u74dc",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u5188\u6bd4\u4e9a",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u82cf\u91cc\u5357",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u585e\u820c\u5c14",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u683c\u9675\u5170",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u7279\u514b\u65af\u548c\u51ef\u79d1\u65af\u7fa4\u5c9b",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u798f\u514b\u5170\u7fa4\u5c9b",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u8499\u7279\u585e\u62c9\u7279",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u4e2d\u975e\u5171\u548c\u56fd",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u5723\u6587\u68ee\u7279\u548c\u683c\u6797\u7eb3\u4e01\u65af",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u5317\u9a6c\u91cc\u4e9a\u7eb3\u7fa4\u5c9b\u8054\u90a6",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u683c\u6797\u90a3\u8fbe",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u5723\u5176\u8328\u548c\u5c3c\u7ef4\u65af",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u5e93\u62c9\u7d22\u5c9b",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u535a\u8328\u74e6\u7eb3",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u5723\u5362\u897f\u4e9a",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u7eb3\u7c73\u6bd4\u4e9a",
#                     "value": 16
#                 },
#                 {
#                     "name": "\u591a\u7c73\u5c3c\u514b",
#                     "value": 16
#                 },
#                 {
#                     "name": "\u6590\u6d4e",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u9a6c\u62c9\u7ef4",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u4f2f\u5229\u5179",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u4e1c\u5e1d\u6c76",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u65b0\u5580\u91cc\u591a\u5c3c\u4e9a",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u8001\u631d",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u82f1\u56fd\uff08\u542b\u5317\u7231\u5c14\u5170\uff09",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u5927\u4e0d\u5217\u98a0\u53ca\u5317\u7231\u5c14\u5170\u8054\u5408\u738b\u56fd",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u81f3\u5c0a\u516c\u4e3b\u90ae\u8f6e",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u65af\u5a01\u58eb\u5170",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u5b89\u63d0\u74dc\u548c\u5df4\u5e03\u8fbe",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u5b89\u54e5\u62c9",
#                     "value": 24
#                 },
#                 {
#                     "name": "\u6d25\u5df4\u5e03\u97e6",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u585e\u62c9\u5229\u6602",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u5c3c\u6cca\u5

# %%
df = pd.read_json('data/json/DXYOverall.json')
ret_dict = df['results'].loc[0]
ret_dict
# Out:
# {'currentConfirmedCount': 1734,
#  'currentConfirmedIncr': -60,
#  'confirmedCount': 84201,
#  'confirmedIncr': 21,
#  'suspectedCount': 1575,
#  'suspectedIncr': 9,
#  'curedCount': 77825,
#  'curedIncr': 81,
#  'deadCount': 4642,
#  'deadIncr': 0,
#  'seriousCount': 999,
#  'seriousIncr': -18,
#  'generalRemark': '1. 3 月 12 日国家卫健委确诊补订遗漏 12 例确诊病例（非 12 日新增），暂无具体省份信息。 2. 浙江省 12 例外省治愈暂无具体省份信息。',
#  'remark1': '易感人群：人群普遍易感。老年人及有基础疾病者感染后病情较重，儿童及婴幼儿也有发病',
#  'remark2': '潜伏期：一般为 3～7 天，最长不超过 14 天，潜伏期内可能存在传染性，其中无症状病例传染性非常罕见',
#  'remark3': '宿主：野生动物，可能为中华菊头蝠',
#  'remark4': '',
#  'remark5': '',
#  'note1': '病毒：SARS-CoV-2，其导致疾病命名 COVID-19',
#  'note2': '传染源：新冠肺炎的患者。无症状感染者也可能成为传染源。',
#  'note3': '传播途径：经呼吸道飞沫、接触传播是主要的传播途径。气溶胶传播和消化道等传播途径尚待明确。',
#  'updateTime': 1587275519060}

# %%
df = pd.read_json('data/json/DXYArea.json')
ret_list = list(df['results'])
df = pd.DataFrame(ret_list)

df = df[(df['countryName'] == df['provinceName']) & (df['currentConfirmedCount'] > 1000)]

def top(df):
    return df[(df['updateTime'] == df['updateTime'].max()) &
              (df['currentConfirmedCount'] == df['currentConfirmedCount'].max())]
df = df.groupby('countryName').apply(top)
# 排序
df.sort_values(by='currentConfirmedCount', ascending=True, inplace=True)
df.drop('countryName', axis=1, inplace=True)
df.reset_index(inplace=True)
df.tail()

# 绘图
# Draw plot
plt.figure(figsize=(10,20), dpi= 80)
plt.hlines(y=df.index, xmin=0, xmax=df['currentConfirmedCount'], color='red', alpha=0.4, linewidth=5)

# Decorations
# gca：当前的子图；gcf：当前图表figure
plt.gca().set(ylabel='国家', xlabel='人数')
plt.yticks(df.index, df['countryName'], fontsize=12)
plt.title('全球现存确诊人数', fontdict={'size':20})
plt.grid(linestyle='--', alpha=0.5)
for x, y in zip(df['currentConfirmedCount'], df.index):
    plt.text(x+20000, y, str(x), ha='center', va='center', fontsize=10.5)
plt.show()
# Out:
#    countryName  level_1  locationId continentName continentEnglishName  \
# 61         土耳其       60      955018            亚洲                 Asia
# 62         西班牙      110      965015            欧洲               Europe
# 63          英国      143      961007            欧洲               Europe
# 64         意大利      146      965008            欧洲               Europe
# 65          美国       10      971002           北美洲        North America
#
#           countryEnglishName provinceName       provinceEnglishName  \
# 61                    Turkey          土耳其                    Turkey
# 62                     Spain          西班牙                     Spain
# 63            United Kingdom           英国            United Kingdom
# 64                     Italy          意大利                     Italy
# 65  United States of America           美国  United States of America
#
#    provinceShortName  currentConfirmedCount  confirmedCount  suspectedCount  \
# 61               土耳其                  69986           82329               0
# 62               西班牙                  97021          191726               0
# 63                英国                  98409          114217               0
# 64               意大利                 107771          175925               0
# 65                美国                 629465          734969               0
#
#     curedCount  deadCount comment cities     updateTime
# 61       10453       1890           None  1587266441583
# 62       74662      20043           None  1587261683092
# 63         344      15464           None  1587261683092
# 64       44927      23227           None  1587261683092
# 65       66601      38903           None  1587266623781
# [Text(0, 0.5, '国家'), Text(0.5, 0, '人数')]
# ([<matplotlib.axis.YTick at 0x1a2420a650>,
#   <matplotlib.axis.YTick at 0x1a24204d10>,
#   <matplotlib.axis.YTick at 0x1a2045be50>,
#   <matplotlib.axis.YTick at 0x1a20458890>,
#   <matplotlib.axis.YTick at 0x1a20458610>,
#   <matplotlib.axis.YTick at 0x1a24214610>,
#   <matplotlib.axis.YTick at 0x1a24214c90>,
#   <matplotlib.axis.YTick at 0x1a2043a310>,
#   <matplotlib.axis.YTick at 0x1a2043a950>,
#   <matplotlib.axis.YTick at 0x1a2043a810>,
#   <matplotlib.axis.YTick at 0x1a24214a90>,
#   <matplotlib.axis.YTick at 0x1a24214e10>,
#   <matplotlib.axis.YTick at 0x1a20470590>,
#   <matplotlib.axis.YTick at 0x1a20470bd0>,
#   <matplotlib.axis.YTick at 0x1a203e9250>,
#   <matplotlib.axis.YTick at 0x1a203e9890>,
#   <matplotlib.axis.YTick at 0x1a203e9ed0>,
#   <matplotlib.axis.YTick at 0x1a203ef550>,
#   <matplotlib.axis.YTick at 0x1a203e9810>,
#   <matplotlib.axis.YTick at 0x1a24214490>,
#   <matplotlib.axis.YTick at 0x1a203efc10>,
#   <matplotlib.axis.YTick at 0x1a2045a290>,
#   <matplotlib.axis.YTick at 0x1a2045a8d0>,
#   <matplotlib.axis.YTick at 0x1a2045af10>,
#   <matplotlib.axis.YTick at 0x1a20437590>,
#   <matplotlib.axis.YTick at 0x1a20437bd0>,
#   <matplotlib.axis.YTick at 0x1a20447250>,
#   <matplotlib.axis.YTick at 0x1a2045afd0>,
#   <matplotlib.axis.YTick at 0x1a203efcd0>,
#   <matplotlib.axis.YTick at 0x1a204476d0>,
#   <matplotlib.axis.YTick at 0x1a20447e50>,
#   <matplotlib.axis.YTick at 0x1a204c64d0>,
#   <matplotlib.axis.YTick at 0x1a204c6b10>,
#   <matplotlib.axis.YTick at 0x1a204bc1d0>,
#   <matplotlib.axis.YTick at 0x1a204bc7d0>,
#   <matplotlib.axis.YTick at 0x1a204bce10>,
#   <matplotlib.axis.YTick at 0x1a204a0490>,
#   <matplotlib.axis.YTick at 0x1a204bc310>,
#   <matplotlib.axis.YTick at 0x1a20437350>,
#   <matplotlib.axis.YTick at 0x1a204a09d0>,
#   <matplotlib.axis.YTick at 0x1a204a0e50>,
#   <matplotlib.axis.YTick at 0x1a20495690>,
#   <matplotlib.axis.YTick at 0x1a20495cd0>,
#   <matplotlib.axis.YTick at 0x1a20490350>,
#   <matplotlib.axis.YTick at 0x1a20490990>,
#   <matplotlib.axis.YTick at 0x1a20490a90>,
#   <matplotlib.axis.YTick at 0x1a20495d50>,
#   <matplotlib.axis.YTick at 0x1a204a00d0>,
#   <matplotlib.axis.YTick at 0x1a1fc2d510>,
#   <matplotlib.axis.YTick at 0x1a1fc2dc10>,
#   <matplotlib.axis.YTick at 0x1a1fc2a290>,
#   <matplotlib.axis.YTick at 0x1a1fc2a8d0>,
#   <matplotlib.axis.YTick at 0x1a1fc2af10>,
#   <matplotlib.axis.YTick at 0x1a1fc23590>,
#   <matplotlib.axis.YTick at 0x1a1fc23bd0>,
#   <matplotlib.axis.YTick at 0x1a1fc1c250>,
#   <matplotlib.axis.YTick at 0x1a1fc23650>,
#   <matplotlib.axis.YTick at 0x1a1fc2d690>,
#   <matplotlib.axis.YTick at 0x1a1fc1c790>,
#   <matplotlib.axis.YTick at 0x1a1fc1cdd0>,
#   <matplotlib.axis.YTick at 0x1a1fc18450>,
#   <matplotlib.axis.YTick at 0x1a1fc18a90>,
#   <matplotlib.axis.YTick at 0x1a1fc0d050>,
#   <matplotlib.axis.YTick at 0x1a1fc0d750>,
#   <matplotlib.axis.YTick at 0x1a1fc0dd90>,
#   <matplotlib.axis.YTick at 0x1a1fc0d1d0>],
#  <a list of 66 Text yticklabel objects>)
# Text(0.5, 1.0, '全球现存确诊人数')
# Text(21010, 0, '1010')
# Text(21019, 1, '1019')
# Text(21057, 2, '1057')
# Text(21178, 3, '1178')
# Text(21273, 4, '1273')
# Text(21290, 5, '1290')
# Text(21306, 6, '1306')
# Text(21312, 7, '1312')
# Text(21431, 8, '1431')
# Text(21466, 9, '1466')
# Text(21734, 10, '1734')
# Text(21903, 11, '1903')
# Text(21941, 12, '1941')
# Text(21994, 13, '1994')
# Text(22079, 14, '2079')
# Text(22106, 15, '2106')
# Text(22107, 16, '2107')
# Text(22115, 17, '2115')
# Text(22234, 18, '2234')
# Text(22385, 19, '2385')
# Text(23224, 20, '3224')
# Text(23370, 21, '3370')
# Text(23581, 22, '3581')
# Text(23903, 23, '3903')
# Text(23926, 24, '3926')
# Text(24005, 25, '4005')
# Text(24148, 26, '4148')
# Text(24394, 27, '4394')
# Text(24490, 28, '4490')
# Text(24698, 29, '4698')
# Text(25077, 30, '5077')
# Text(25078, 31, '5078')
# Text(25174, 32, '5174')
# Text(25198, 33, '5198')
# Text(25298, 34, '5298')
# Text(25411, 35, '5411')
# Text(25569, 36, '5569')
# Text(25793, 37, '5793')
# Text(26271, 38, '6271')
# Text(26398, 39, '6398')
# Text(26846, 40, '6846')
# Text(26853, 41, '6853')
# Text(26873, 42, '6873')
# Text(27388, 43, '7388')
# Text(27414, 44, '7414')
# Text(28065, 45, '8065')
# Text(28733, 46, '8733')
# Text(29809, 47, '9809')
# Text(29854, 48, '9854')
# Text(32404, 49, '12404')
# Text(32974, 50, '12974')
# Text(34125, 51, '14125')
# Text(38388, 52, '18388')
# Text(39850, 53, '19850')
# Text(40226, 54, '20226')
# Text(42184, 55, '22184')
# Text(43382, 56, '23382')
# Text(47697, 57, '27697')
# Text(53423, 58, '33423')
# Text(67603, 59, '47603')
# Text(76515, 60, '56515')
# Text(89986, 61, '69986')
# Text(117021, 62, '97021')
# Text(118409, 63, '98409')
# Text(127771, 64, '107771')
# Text(649465, 65, '629465')
